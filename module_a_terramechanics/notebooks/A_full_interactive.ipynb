# %% [markdown]
# <a href="https://colab.research.google.com/github/Moha4321/fuji-icebreaker-physics/blob/main/module_a_terramechanics/notebooks/A_full_interactive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CELL 1: Environment Setup
import os
import sys

# Define the repo details
REPO_NAME = "fuji-icebreaker-physics"
GITHUB_URL = f"https://github.com/Moha4321/{REPO_NAME}.git" # <-- CHANGE USERNAME

# Clone the repo if it doesn't exist in the Colab VM
if not os.path.exists(REPO_NAME):
    # !git clone {GITHUB_URL}

# Move into the project directory
os.chdir(REPO_NAME)

# Pull the latest changes (in case you updated code on your Mac)
# !git pull origin main

# Add the project root to Python's path so you can import your custom modules
sys.path.append(os.path.abspath('.'))

# Install required Colab packages (JAX, Taichi, GUDHI)
# !pip install -r requirements_colab.txt -q

print(f"Successfully mounted {REPO_NAME} and installed dependencies!")
# Out:
# Cloning into 'fuji-icebreaker-physics'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# From https://github.com/Moha4321/fuji-icebreaker-physics
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Successfully mounted fuji-icebreaker-physics and installed dependencies!

# %%
# !ls
